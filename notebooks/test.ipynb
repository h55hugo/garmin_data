# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Nougarède Hugo\Documents\Programming\garmin_data\notebooks

# %%
cd ..
# Out:
# c:\Users\Nougarède Hugo\Documents\Programming\garmin_data

# %%
from src.fetch_data import fetch_data

# Process raw garmin data

raw_data = fetch_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.fetch_data import fetch_data
#       3 # Process raw garmin data
#       5 raw_data = fetch_data()
#
# File c:\Users\Nougarède Hugo\Documents\Programming\garmin_data\src\fetch_data.py:5
#       3 from garminconnect import Garmin
#       4 import pandas as pd
# ----> 5 from config import EMAIL, PASSWORD
#       8 def fetch_data(n_activities=50):
#       9     """Fetch the last raw n_activites available on garmin connect."""
#
# ModuleNotFoundError: No module named 'config'

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
raw_data.head()
# Out:
#     activityId          activityName       startTimeLocal  \
# 0  20185650353  Lavigny Road Cycling  2025-08-26 17:19:33
# 1  20165465242  Lavigny Road Cycling  2025-08-24 18:54:06
# 2  19973290005  Lavigny Road Cycling  2025-08-06 18:19:40
# 3  19973255011  Lavigny Road Cycling  2025-08-03 10:14:54
# 4  19897077988  Lavigny Road Cycling  2025-07-30 16:30:19
#
#           startTimeGMT                                       activityType  \
# 0  2025-08-26 15:19:33  {'typeId': 10, 'typeKey': 'road_biking', 'pare...
# 1  2025-08-24 16:54:06  {'typeId': 10, 'typeKey': 'road_biking', 'pare...
# 2  2025-08-06 16:19:40  {'typeId': 10, 'typeKey': 'road_biking', 'pare...
# 3  2025-08-03 08:14:54  {'typeId': 10, 'typeKey': 'road_biking', 'pare...
# 4  2025-07-30 14:30:19  {'typeId': 10, 'typeKey': 'road_biking', 'pare...
#
#                                            eventType      distance  \
# 0  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...  38382.351562
# ...

# %%
import sys
print(sys.path)
# sys.path.append("C:/Users/Nougarède Hugo/Documents/Programming/garmin_data")
# Out:
# ['C:\\Users\\Nougarède Hugo\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\Nougarède Hugo\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\Nougarède Hugo\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\Nougarède Hugo\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\Nougarède Hugo\\Documents\\Programming\\garmin_data\\venv', '', 'c:\\Users\\Nougarède Hugo\\Documents\\Programming\\garmin_data\\venv\\Lib\\site-packages', 'c:\\Users\\Nougarède Hugo\\Documents\\Programming\\garmin_data\\venv\\Lib\\site-packages\\win32', 'c:\\Users\\Nougarède Hugo\\Documents\\Programming\\garmin_data\\venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Nougarède Hugo\\Documents\\Programming\\garmin_data\\venv\\Lib\\site-packages\\Pythonwin', 'C:/Users/Nougarède Hugo/Documents/Programming/garmin_data']

# %%
from datetime import datetime

# define your dates
d1 = datetime(2026, 5, 11)
d2 = datetime(2026, 8, 30)

# extract ISO year + week
y1, w1, _ = d1.isocalendar()
y2, w2, _ = d2.isocalendar()

# compute difference in weeks
weeks_between = (y2 - y1) * 52 + (w2 - w1)

print(weeks_between)
# Out:
# 15
