# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# =========================
# CONFIG
# =========================
START_DATE = pd.to_datetime("2026-02-02")  # Monday
RACE_DATE = pd.to_datetime("2026-08-30")   # Sunday



# =========================
# LOAD DATA
# =========================
df = pd.read_csv("../csv/Lausanne_Triathlon_2026/main.csv")
df["activity_date"] = pd.to_datetime(df["activity_date"])

# =========================
# TRAINING WEEK (MONDAY-BASED)
# =========================
df = df[df["activity_date"] >= START_DATE].copy()

df["training_week"] = (
    (df["activity_date"] - START_DATE).dt.days // 7
) + 1

start = pd.to_datetime("2026-02-16")
end = pd.to_datetime("2026-02-22")

df[
    (df["activity_date"] >= start) &
    (df["activity_date"] <= end)
]["duration"].sum() / 3600

df[
    (df["activity_date"] >= start) &
    (df["activity_date"] <= end)
]
# Out:
#      activityId activity_date activity_time  distance_km  duration  \
# 29  21895004658    2026-02-17      12:27:13         4.27   1971.60
# 30  21903434308    2026-02-18      06:00:33        19.14   3001.39
# 31  21924237615    2026-02-20      06:06:12         5.50   2634.40
# 32  21934615265    2026-02-21      08:03:34        10.19   4757.40
# 33  21951873467    2026-02-22      11:30:16        12.60   8163.38
#
#     elevationGain  elevationLoss  averageSpeed  maxSpeed    ownerId  ...  \
# 29           25.0           22.0          7.80      2.86  121637100  ...
# 30            NaN            NaN         22.95      7.24  121637100  ...
# 31           39.0           40.0          7.51      3.15  121637100  ...
# 32          137.0          136.0          7.71      5.09  121637100  ...
# 33          211.0          202.0          5.56      6.55  121637100  ...
#
#       deviceId  locationName moderateIntensityMinutes  \
# 29  3614308067       Lavigny                      2.0
# 30  3466268921           NaN                     31.0
# 31  3614308067       Lavigny                      5.0
# 32  3614308067       Lavigny                     18.0
# 33  3614308067       Lamoura                     86.0
#
#     vigorousIntensityMinutes     zone1      zone2      zone3     zone4  \
# 29                      30.0   138.000   2088.006   8066.058  1481.904
# 30                      15.0   408.000  15252.690   1110.006     0.000
# 31                      38.0   228.006   3407.844  10919.208  1155.720
# 32                      60.0   324.000   2357.904  17909.454  7766.292
# 33                      26.0  6255.930  19665.895  12483.825  2115.020
#
#       zone5  training_week
# 29    0.000              3
# 30    0.000              3
# 31    0.000              3
# 32  150.006              3
# 33    0.000              3
#
# [5 rows x 25 columns]
